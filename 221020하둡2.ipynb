# %% [markdown]
# <a href="https://colab.research.google.com/github/hkhong72/big_data/blob/main/221020%ED%95%98%EB%91%A12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 샘플은 jar파일로 패키징되어있음
#
# yarn jar hadoop-3.2.4/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.2.4.jar wordcount sample-input sample-output
#
# sample-output은 없는 디렉토리로 설정해야함
# jar안에 wordcount라는 클래스가 존재
#
# hdfs dfs -ls 로 sample-output 있나확인
#
# hdfs dfs -cat sample-ouput/part-r-00000 (단어수세서나옴)

# %% [markdown]
# ~/hadoop-3.2.4/etc/hadoop
#
# vi mapred-site.xml
# 에 HADDOP으로 되어있어서 오류남ㅅㅂ

# %% [markdown]
# 리눅스에서
# localhost:50070 -> 확인
#
# localhost:8088 -> 하둡관련모든것확인
#
# localhost:19888   -> JobHistory확인
#
# 에서 해당내용확인가능

# %% [markdown]
# 슬랙에서 mapreduce.pdf 확인

# %% [markdown]
# ![제목 없음.png](data:image/png;base64,...)

# %% [markdown]
# wordcount를 직접짜보기
#
# 하둡을 내려놓고 리눅스를 꺼야함.
#
# 리눅스부터 끄면 재수없으면 하둡파일깨짐
#
# 방법 ->
#
# JobHistoryServer 죽이는법
#
# jps
#
# kill -9 JobHistoryServer 번호
#
# jps
#
# JobHistoryServer 죽은것확인
#
# stop-yarn.sh
#
# stop-dfs.sh
#
# jps
#
# 로 다 죽었나확인

# %% [markdown]
# # 이클립스에 Maven Project만들기
#
# create simple Project 체크
#
# com.adacho
#
# hadoopMR
#
# 0.1~~ 기본셋팅
#
# jar 기본셋팅
#
# 프로젝트생성
